# %% [markdown]
# ![image.png](attachment:image.png)

# %%
inputs = [1.0, 2.0, 3.0]
weights = [0.2, 0.8, -0.5]
bias = 2.0
output = inputs[0]*weights[0] + inputs[1]*weights[1] + inputs[2]*weights[2] + bias
print(output)
# Out:
# 2.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
inputs = [1.2, 4.5, 9.1, 6.7]
weights1 = [0.76, 0.21, -0.59, 0.76]
weights2 = [0.6, -0.8, 0.65, 0.21]
weights3 = [-0.2, 0.9, 0.43, 0.22]

bias1 = 2.0
bias2 = 7.0
bias3 = 9.0

output =[
         inputs[0]*weights1[0] + inputs[1]*weights1[1] + inputs[2]*weights1[2] + inputs[3]*weights1[3] + bias1,
         inputs[0]*weights2[0] + inputs[1]*weights2[1] + inputs[2]*weights2[2] + inputs[3]*weights2[3] + bias2,
         inputs[0]*weights3[0] + inputs[1]*weights3[1] + inputs[2]*weights3[2] + inputs[3]*weights3[3] + bias3
]
print(output)
# Out:
# [3.5800000000000005, 11.442, 18.197]

# %%
inputs = [1.2, 4.5, 9.1, 6.7]

weights = [[0.76, 0.21, -0.59, 0.76],
            [0.6, -0.8, 0.65, 0.21],
            [-0.2, 0.9, 0.43, 0.22]]

bias = [2.0, 7.0 ,9.0]

layer_output = []
for neuron_weights, neuron_bias in zip(weights, bias):
    neuron_output = 0
    for n_input, weights in zip(inputs, neuron_weights):
        neuron_output += n_input*weights
    neuron_output += neuron_bias
    layer_output.append(neuron_output)
print(layer_output)
# Out:
# [3.5800000000000005, 11.442, 18.197]

# %%
import numpy as np

inputs = [1.0, 2.0, 3.0]
weights = [0.2, 0.8, -0.5]
bias = 2.0
output = np.dot(input, weights) + bias
print(output)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       4 weights = [0.2, 0.8, -0.5]
#       5 bias = 2.0
# ----> 6 output = np.dot(input, weights)+ bias
#       7 print(output)
#
# TypeError: unsupported operand type(s) for *: 'method' and 'float'
